# %%
# %fs

ls /FileStore/Ashish_SaleAnalysis/Country=Australia/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2010-12-01/</td><td>Invoice_Date=2010-12-01/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2010-12-08/</td><td>Invoice_Date=2010-12-08/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2010-12-14/</td><td>Invoice_Date=2010-12-14/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2010-12-17/</td><td>Invoice_Date=2010-12-17/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-06/</td><td>Invoice_Date=2011-01-06/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-10/</td><td>Invoice_Date=2011-01-10/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-11/</td><td>Invoice_Date=2011-01-11/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-14/</td><td>Invoice_Date=2011-01-14/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-17/</td><td>Invoice_Date=2011-01-17/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-19/</td><td>Invoice_Date=2011-01-19/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-20/</td><td>Invoice_Date=2011-01-20/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-01-28/</td><td>Invoice_Date=2011-01-28/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-02-07/</td><td>Invoice_Date=2011-02-07/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-02-15/</td><td>Invoice_Date=2011-02-15/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-02-27/</td><td>Invoice_Date=2011-02-27/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-03-03/</td><td>Invoice_Date=2011-03-03/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-03-09/</td><td>Invoice_Date=2011-03-09/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-03-24/</td><td>Invoice_Date=2011-03-24/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-04-01/</td><td>Invoice_Date=2011-04-01/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-04-04/</td><td>Invoice_Date=2011-04-04/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-04-08/</td><td>Invoice_Date=2011-04-08/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-04-28/</td><td>Invoice_Date=2011-04-28/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-05-12/</td><td>Invoice_Date=2011-05-12/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-05-17/</td><td>Invoice_Date=2011-05-17/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2011-05-20/</td><td>Invoice_Date=2011-05-20/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/Ashish_SaleAnalysis/Country=Australia/Invoice_Date=2 ...

# %%
ls /FileStore/tables

# %%
'''%run is command to import any other notebook and its avaibale methods'''
# Out:
# Out[35]: '%run is command to import any other notebook and its avaibale methods'

# %%
# %run "./utility"

# %%
##All required modules/method/function will be declare here
import uuid
from pyspark.sql import functions as f

##Constant variables
job_run_env ='local'
appName ='CreditCardFarud'
location ="/FileStore/tables/invoices.csv"
fileType ="csv"

# %%
job_run_id = uuid.uuid4()
###Initialise Spark Application
print("Initializing " + appName + " Job in " +  str(job_run_env) + " Job Id: " + str(job_run_id))

#createSparkAppSession method is available in utility module and called from here
spark =createSparkAppSession(job_run_env,appName)

#get_invoice_schema method is available in utility module and called from here
schema = get_invoice_schema()

#readDataFromFiles method is available in utility module and called from here
raw_df = readDataFromFiles(spark,fileType,schema,location)
# Out:
# Initializing CreditCardFarud Job in local Job Id: e059f997-f530-4496-831d-1787abd0604a

# %%
##Take Total count of records available in raw dataframe
#541909
print("Total available row in raw dataframe - " + str(raw_df.count()))
      
            
#Check schema exploaration
display(raw_df)
raw_df.printSchema()
# Out:
# Total available row in raw dataframe -541909
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Invoice_No</th><th>Stock_Code</th><th>Description</th><th>quantity</th><th>Invoice_Date</th><th>Unit_Price</th><th>Customer_ID</th><th>Country</th></tr></thead><tbody><tr><td>536365</td><td>null</td><td>WHITE HANGING HEART T-LIGHT HOLDER</td><td>6</td><td>01-12-2010 8.26</td><td>2.55</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>71053</td><td>WHITE METAL LANTERN</td><td>6</td><td>01-12-2010 8.26</td><td>3.39</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84406B</td><td>CREAM CUPID HEARTS COAT HANGER</td><td>8</td><td>01-12-2010 8.26</td><td>2.75</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029G</td><td>KNITTED UNION FLAG HOT WATER BOTTLE</td><td>6</td><td>01-12-2010 8.26</td><td>3.39</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>84029E</td><td>RED WOOLLY HOTTIE WHITE HEART.</td><td>6</td><td>01-12-2010 8.26</td><td>3.39</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>22752</td><td>SET 7 BABUSHKA NESTING BOXES</td><td>2</td><td>01-12-2010 8.26</td><td>7.65</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536365</td><td>21730</td><td>GLASS STAR FROSTED T-LIGHT HOLDER</td><td>6</td><td>01-12-2010 8.26</td><td>4.25</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22633</td><td>HAND WARMER UNION JACK</td><td>6</td><td>01-12-2010 8.28</td><td>1.85</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536366</td><td>22632</td><td>HAND WARMER RED POLKA DOT</td><td>6</td><td>01-12-2010 8.28</td><td>1.85</td><td>17850</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84879</td><td>ASSORTED COLOUR BIRD ORNAMENT</td><td>32</td><td>01-12-2010 8.34</td><td>1.69</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22745</td><td>POPPY'S PLAYHOUSE BEDROOM </td><td>6</td><td>01-12-2010 8.34</td><td>2.1</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22748</td><td>POPPY'S PLAYHOUSE KITCHEN</td><td>6</td><td>01-12-2010 8.34</td><td>2.1</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22749</td><td>FELTCRAFT PRINCESS CHARLOTTE DOLL</td><td>8</td><td>01-12-2010 8.34</td><td>3.75</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22310</td><td>IVORY KNITTED MUG COSY </td><td>6</td><td>01-12-2010 8.34</td><td>1.65</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>84969</td><td>BOX OF 6 ASSORTED COLOUR TEASPOONS</td><td>6</td><td>01-12-2010 8.34</td><td>4.25</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22623</td><td>BOX OF VINTAGE JIGSAW BLOCKS </td><td>3</td><td>01-12-2010 8.34</td><td>4.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>22622</td><td>BOX OF VINTAGE ALPHABET BLOCKS</td><td>2</td><td>01-12-2010 8.34</td><td>9.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21754</td><td>HOME BUILDING BLOCK WORD</td><td>3</td><td>01-12-2010 8.34</td><td>5.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21755</td><td>LOVE BUILDING BLOCK WORD</td><td>3</td><td>01-12-2010 8.34</td><td>5.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>21777</td><td>RECIPE BOX WITH METAL HEART</td><td>4</td><td>01-12-2010 8.34</td><td>7.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536367</td><td>48187</td><td>DOORMAT NEW ENGLAND</td><td>4</td><td>01-12-2010 8.34</td><td>7.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22960</td><td>JAM MAKING SET WITH JARS</td><td>6</td><td>01-12-2010 8.34</td><td>4.25</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22913</td><td>RED COAT RACK PARIS FASHION</td><td>3</td><td>01-12-2010 8.34</td><td>4.95</td><td>13047</td><td>United Kingdom</td></tr><tr><td>536368</td><td>22912</td><td>YELLOW COAT RACK PARIS FASHION</t ...
# root
#  |-- Invoice_No: integer (nullable = true)
#  |-- Stock_Code: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- Invoice_Date: string (nullable = true)
#  |-- Unit_Price: double (nullable = true)
#  |-- Customer_ID: integer (nullable = true)
#  |-- Country: string (nullable = true)

# %%
#Perfrom neceassry Data type conversion 
spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")
df_transf1 = raw_df.withColumn("Invoice_DateTime",f.to_timestamp(raw_df.Invoice_Date,"dd-MM-yyyy HH.mm"))\
                .withColumn("Invoice_Date",f.to_date(raw_df.Invoice_Date,"dd-MM-yyyy"))

#Filter all the record not having invoice number and derive dummy invoice number 
df_Without_InvoiceNo = df_correctDataTypes.filter(df_correctDataTypes.Invoice_No.isNull())\
                                           .withColumn("Invoice_No",f.when(df_correctDataTypes.Invoice_No.isNull(),"DUM-01")
                                               .otherwise(df_correctDataTypes.Invoice_No))

#Filter all the record having invoice number
df_with_InvoiceNo = df_correctDataTypes.filter(df_correctDataTypes.Invoice_No.isNotNull())

#combining dataframes having Dummy invoice number 
df_refined = df_with_InvoiceNo.union(df_Without_InvoiceNo)
#df_refined.filter(df_refined.Invoice_No =='DUM-01').show()
#display(df_refined)

# %%
'''
#raw_df.select('Invoice_No','Stock_Code','Description','quantity',f.col('Invoice_Date').cast('Date'),'Unit_Price','Customer_ID','Country').show()
df_correctDataTypes.filter("quantity is NULL").show()

df_correctDataTypes.fillna(value='0')

'''
# Out:
# Out[56]: '\n#raw_df.select(\'Invoice_No\',\'Stock_Code\',\'Description\',\'quantity\',f.col(\'Invoice_Date\').cast(\'Date\'),\'Unit_Price\',\'Customer_ID\',\'Country\').show()\ndf_correctDataTypes.filter("quantity is NULL").show()\n\ndf_correctDataTypes.fillna(value=\'0\')\n\n'

# %%
##Analysis performed to indentied columns for partion while saving into data file
df_refined.select('Invoice_Date','Country').distinct().show()
# Out:
# +------------+--------------+
# |Invoice_Date|       Country|
# +------------+--------------+
# |  2010-12-03|        France|
# |  2010-12-03|United Kingdom|
# |  2010-12-03|      Portugal|
# |  2010-12-01|        Norway|
# |  2010-12-01|          EIRE|
# |  2010-12-03|        Poland|
# |  2010-12-05|United Kingdom|
# |  2010-12-03|         Italy|
# |  2010-12-03|       Germany|
# |  2010-12-02|          EIRE|
# |  2010-12-03|          EIRE|
# |  2010-12-03|   Switzerland|
# |  2010-12-01|     Australia|
# |  2010-12-01|   Netherlands|
# |  2010-12-02|United Kingdom|
# |  2010-12-03|       Belgium|
# |  2010-12-01|       Germany|
# |  2010-12-03|         Spain|
# |  2010-12-01|United Kingdom|
# |  2010-12-02|       Germany|
# +------------+--------------+
# only showing top 20 rows

# %%
###Writing refined dataframe into parquet file format for further transformation via sql process

df_refined.write\
          .partitionBy("Country","Invoice_Date")\
          .parquet("/FileStore/Ashish_SaleAnalysis/")

# %%
#Read parquet file data & create a TempView for further business logic implementation
df_raw_salesdata = spark.read.parquet("/FileStore/Ashish_SaleAnalysis/")
display(df_raw_salesdata)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Invoice_No</th><th>Stock_Code</th><th>Description</th><th>quantity</th><th>Unit_Price</th><th>Customer_ID</th><th>Invoice_DateTime</th><th>Country</th><th>Invoice_Date</th></tr></thead><tbody><tr><td>580538</td><td>23084</td><td>RABBIT NIGHT LIGHT</td><td>48</td><td>1.79</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>23077</td><td>DOUGHNUT LIP GLOSS </td><td>20</td><td>1.25</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>22906</td><td>12 MESSAGE CARDS WITH ENVELOPES</td><td>24</td><td>1.65</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>21914</td><td>BLUE HARMONICA IN BOX </td><td>24</td><td>1.25</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>22467</td><td>GUMBALL COAT RACK</td><td>6</td><td>2.55</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>21544</td><td>SKULLS  WATER TRANSFER TATTOOS </td><td>48</td><td>0.85</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>23126</td><td>FELTCRAFT GIRL AMELIE KIT</td><td>8</td><td>4.95</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580538</td><td>21833</td><td>CAMOUFLAGE LED TORCH</td><td>24</td><td>1.69</td><td>14075</td><td>2011-12-05T08:38:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580539</td><td>21479</td><td>WHITE SKULL HOT WATER BOTTLE </td><td>4</td><td>4.25</td><td>18180</td><td>2011-12-05T08:39:00.000+0000</td><td>United Kingdom</td><td>2011-12-05</td></tr><tr><td>580539</td><td